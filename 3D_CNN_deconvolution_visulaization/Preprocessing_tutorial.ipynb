# %%
import numpy as np
import os,cv2
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import scipy.ndimage
def process_data(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
#  
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (2/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient

def flip_data1(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
    slices = [cv2.flip(np.array(each_slice),(1)) for each_slice in slices]
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (28/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient
def rotate1(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
    slices = [scipy.misc.imrotate(np.array(each_slice),(10)) for each_slice in slices]
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (28/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient
def rotate2(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
    slices = [scipy.misc.imrotate(np.array(each_slice),(20)) for each_slice in slices]
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (28/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient
def rotate3(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
    slices = [scipy.misc.imrotate(np.array(each_slice),(30)) for each_slice in slices]
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (28/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient
def rotate_1(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
    slices = [scipy.misc.imrotate(np.array(each_slice),(-10)) for each_slice in slices]
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (28/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient
def rotate_2(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
    slices = [scipy.misc.imrotate(np.array(each_slice),(-20)) for each_slice in slices]
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (28/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient
def rotate_3(patient,ImageSize):
    label = labels.at[patient, 'Hemorrhage']
    
    path = data_dir + patient
    slices = [cv2.imread(path + '/' + s,0) for s in os.listdir(path)]
    slices = [cv2.resize(np.array(each_slice),(ImageSize,ImageSize)) for each_slice in slices]
    slices = [scipy.misc.imrotate(np.array(each_slice),(-30)) for each_slice in slices]
    np.array(slices)
    f=np.array(np.stack((slices)))
    s=len(f)
#     print('length',s)
    f=scipy.ndimage.interpolation.zoom(f, (28/s,1,1), order=2, mode='nearest')
    
#     print(np.shape(f))
    new_slices = []
    new_slices.append(f)
#     print(np.shape(new_slices))
    label1 = []
    if label == 1: label=np.array([0,1])
    elif label == 0: label=np.array([1,0])
#     new_slices=scipy.ndimage.zoom(new_slices, (28/s,1,1))
    label1.append(label)
#     new_slices = list(zip(new_slices, label))
    data = list(*zip(new_slices, label1))
#     print(data)
    return data, patient

# %%
# data_dir = 'D:/NORMvsSAH/Data/UnchangedFolderNameData/Fold2/Train/'
data_dir = 'D:/NORMvsSAH/Data/UnchangedFolderNameData/Fold2/Vald/'
# data_dir = 'D:/NORMvsSAH/Data/UnchangedFolderNameData/Fold2/Test/'
patients = os.listdir(data_dir)
labels = pd.read_csv('D:/NORMvsSAH/Data/UnchangedFolderNameData/csvfile.csv', index_col=0)
np.random.shuffle(patients)
np.random.shuffle(patients)
ImageSize= 10

NewData = []

for num,patient in enumerate(patients[:20]):
    print(num,patient )
    data =process_data(patient,ImageSize)
    NewData.append(data)
    
#     data = flip_data1(patient,ImageSize)
#     NewData.append(data)
    
#     data = rotate1(patient,ImageSize)
#     NewData.append(data)
    
#     data = rotate2(patient,ImageSize)
#     NewData.append(data)
    
#     data = rotate3(patient,ImageSize)
#     NewData.append(data)
    
#     data = rotate_1(patient,ImageSize)
#     NewData.append(data)
    
#     data = rotate_2(patient,ImageSize)
#     NewData.append(data)
    
#     data = rotate_3(patient,ImageSize)
#     NewData.append(data)
    
# np.save('D:/NORMvsSAH/GoogleNet/Train'.format(ImageSize,ImageSize,28), NewData)
# np.save('D:/NORMvsSAH/GoogleNet/Vald'.format(ImageSize,ImageSize,28), NewData)
np.save('D:/NORMvsSAH/GoogleNet/Test'.format(ImageSize,ImageSize,28), NewData)
# Out:
# 0 Patient-S39
# 1 Patient-S71
# 2 Patient-2HIN26
# 3 Patient-S78
# 4 Patient-N8
# 5 Patient-N4
# 6 Patient-S46
# 7 Patient-S44
# 8 Patient-2HIN30
# 9 Patient-S80
# 10 Patient-S43
# 11 Patient-S72
# 12 Patient-2HIN29
# 13 Patient-2HIN28
# 14 Patient-2HIN27
# 15 Patient-N11
# 16 Patient-S52
# 17 Patient-S47
# 18 Patient-S41
# 19 Patient-S63

# %%
# NewData[1][1]

for im in NewData:
    b=im[0][1]
    b=im[1]
    print(b)
#     print(b)

# %%
a=NewData[0]
# print(a[0])
# b=a[0]
# c=b[5]
# plt.imshow(c)

# %%
a= np.load('D:/NORMvsSAH/GoogleNet/Test.npy')
np.random.shuffle(a)

for im in a:
    b=im[0][0]
#     b[b>250, ]=0
    print(im[1])
    fig = plt.figure()
    for num, s in enumerate (b):
#         plt.imshow(s, cmap='gray')
#         plt.show()
        y = fig.add_subplot(6,6,num+1)
        y.imshow(s, cmap='gray')
    plt.show()

# %%
for i in range(215):
    print((i*7))

# %%
a=np.load('D:/NORMvsSAH/Data/Trainnnnn.npy')

# %%
np.shape(a)
